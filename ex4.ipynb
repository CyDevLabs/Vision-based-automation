# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D

sigma = 1
step = 0.25
x = np.arange(-5, 5 + step, step)
y = np.arange(-5, 5 + step, step)
X, Y = np.meshgrid(x, y)
g = np.exp(-(X**2 + Y**2)/(2*sigma**2))

kernel = np.array([[0, 0, 0], [-1, 0, 1], [0, 0, 0]])
gy = cv.filter2D(g, -1, kernel)
kernel = np.array([[0, -1, 0], [0, 0, 0], [0, 1, 0]])
gx = cv.filter2D(g, -1, kernel)

fig, ax = plt.subplots(1,3, figsize=(16,8))
ax[0] = fig.add_subplot(131, projection='3d')
ax[1] = fig.add_subplot(132, projection='3d')
ax[2] = fig.add_subplot(133, projection='3d')

surf1 = ax[0].plot_surface(X, Y, g, cmap=cm.jet)
surf1 = ax[1].plot_surface(X, Y, gy, cmap=cm.jet)
surf3 = ax[2].plot_surface(X, Y, gx, cmap=cm.jet)

ax[0].axis('off')
ax[1].axis('off')
ax[2].axis('off')
plt.show()

# %%
# !jupyter nbconvert --to html ex4.ipynb
# Out:
# [NbConvertApp] Converting notebook ex4.ipynb to html
# [NbConvertApp] Writing 787626 bytes to ex4.html
